# %%
#|hide
# from alphazero.search import *

# %% [markdown]
# # AlphaZero
#
# > Implementation of [AlphaZero](https://en.wikipedia.org/wiki/AlphaZero), a decision aid using neural network augmented tree search.

# %% [markdown]
# This project uses the [NBDev](https://github.com/fastai/nbdev/tree/master/) development library.
